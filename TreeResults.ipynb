# %%
import seaborn as sns
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

results = pd.read_csv("experiment-results.csv")
results
# Out:
#     topology1  tau_AB1  tau_ABC1  tau_Root1  p_AB1  p_ABC1  p_Root1 topology2  \
# 0         CAT    10000     20000      30000  10000   10000    10000       CAT
# 1         CAT    10000     20000      30000  10000   10000    10000       CAT
# 2         CAT    10000     20000      30000  10000   10000    10000       CAT
# 3         CAT    10000     20000      30000  10000   10000    10000       CAT
# 4         CAT    10000     20000      30000  10000   10000    10000       CAT
# ..        ...      ...       ...        ...    ...     ...      ...       ...
# 113       CAT    10000     15000      30000  10000   10000    10000       CAT
# 114       CAT    10000     20000      30000  10000   10000    10000       CAT
# 115       CAT    10000     20000      30000  10000   10000    10000       CAT
# 116       CAT     5000     15000      20000  10000   10000    10000       CAT
# 117       CAT     5000     15000      20000  10000   10000    10000       CAT
#
# ...

# %%
empty = results.isna().any(axis =1)
results = results[~empty]
results
# Out:
#     topology1  tau_AB1  tau_ABC1  tau_Root1  p_AB1  p_ABC1  p_Root1 topology2  \
# 0         CAT    10000     20000      30000  10000   10000    10000       CAT
# 1         CAT    10000     20000      30000  10000   10000    10000       CAT
# 2         CAT    10000     20000      30000  10000   10000    10000       CAT
# 3         CAT    10000     20000      30000  10000   10000    10000       CAT
# 4         CAT    10000     20000      30000  10000   10000    10000       CAT
# ..        ...      ...       ...        ...    ...     ...      ...       ...
# 107       CAT    10000     20000      30000  10000   10000    10000       CAT
# 108       CAT    10000     20000      30000  10000   10000    10000       CAT
# 110       CAT    10000     20000      30000  10000   10000    10000       CAT
# 113       CAT    10000     15000      30000  10000   10000    10000       CAT
# 114       CAT    10000     20000      30000  10000   10000    10000       CAT
#
# ...

# %%
attempt = pd.read_csv("experiment-results - Attempt.csv")

empty = attempt.isna().any(axis =1)
attempt = attempt[~empty]

attempt 
#this dataset combines the columns: "Location change in length" and "Location change 
#in population" in the results dataset into one ("Location change").
#Done to use for the hue parameter
# Out:
#     topology1  tau_AB1  tau_ABC1  tau_Root1  p_AB1  p_ABC1  p_Root1 topology2  \
# 0         CAT    10000     20000      30000  10000   10000    10000       CAT
# 1         CAT    10000     20000      30000  10000   10000    10000       CAT
# 2         CAT    10000     20000      30000  10000   10000    10000       CAT
# 3         CAT    10000     20000      30000  10000   10000    10000       CAT
# 4         CAT    10000     20000      30000  10000   10000    10000       CAT
# ..        ...      ...       ...        ...    ...     ...      ...       ...
# 113       CAT    10000     15000      30000  10000   10000    10000       CAT
# 114       CAT    10000     20000      30000  10000   10000    10000       CAT
# 115       CAT    10000     20000      30000  10000   10000    10000       CAT
# 116       CAT     5000     15000      20000  10000   10000    10000       CAT
# 117       CAT     5000     15000      20000  10000   10000    10000       CAT
#
# ...

# %%
#Using how many changes as x

# %%
# Draw a pointplot to show pulse as a function of three categorical factors
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= attempt, x="how many changes", y="Power", hue="Location change", col="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# x=tau_AB2

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= attempt, x="tau_AB2", y="Power", hue="Location change", col="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Using x="tau_ABC2

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= attempt, x="tau_ABC2", y="Power", hue="Location change", col="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Using x = tau_Root2

# %%
# Draw a pointplot to show pulse as a function of three categorical factors
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= attempt, x="tau_Root2", y="Power", hue="Location change", col="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Using x = p_AB2

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= attempt, x="p_AB2", y="Power", hue="Location change", col="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Using x = p_ABC2

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= attempt, x="p_ABC2", y="Power", hue="Location change", col="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Using x = p_Root2

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= attempt, x="p_Root2", y="Power", hue="Location change", col="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#For tree comparisons done with this three as the first tree and at most one change:
#gts_dendropy_CAT_(((AB)C)D)_tauAB-10000_tauABC-20000_tauRoot-30000_pAB-10000_pABC-10000_pRoot-10000

filter1= results["tau_AB1"]==10000
filter2= results["tau_ABC1"]==20000
filter3= results["tau_Root1"]==30000
filter4= results["p_AB1"]==10000
filter5= results["p_ABC1"]==10000
filter6= results["p_Root1"]==10000
filter7= results["how many changes"]<=1 

results1= results[filter1&filter2&filter3&filter4&filter5&filter6&filter7]
results1
# Out:
#    topology1  tau_AB1  tau_ABC1  tau_Root1  p_AB1  p_ABC1  p_Root1 topology2  \
# 0        CAT    10000     20000      30000  10000   10000    10000       CAT
# 1        CAT    10000     20000      30000  10000   10000    10000       CAT
# 2        CAT    10000     20000      30000  10000   10000    10000       CAT
# 3        CAT    10000     20000      30000  10000   10000    10000       CAT
# 4        CAT    10000     20000      30000  10000   10000    10000       CAT
# 5        CAT    10000     20000      30000  10000   10000    10000       CAT
# 6        CAT    10000     20000      30000  10000   10000    10000       CAT
# 7        CAT    10000     20000      30000  10000   10000    10000       CAT
# 8        CAT    10000     20000      30000  10000   10000    10000       CAT
# 9        CAT    10000     20000      30000  10000   10000    10000       CAT
# 10       CAT    10000     20000      30000  10000   10000    10000       CAT
# ...

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= results1, x="tau_AB2", y="Power", hue="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=4, aspect=1,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= results1, x="tau_ABC2", y="Power", hue="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=4, aspect=1,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= results1, x="tau_Root2", y="Power", hue="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=4, aspect=1,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= results1, x="p_AB2", y="Power", hue="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=4, aspect=1,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= results1, x="p_ABC2", y="Power", hue="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=4, aspect=1,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= results1, x="p_Root2", y="Power", hue="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=4, aspect=1,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= results1, x="p_Root2", y="Power", hue="Location change in length", col="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= results1, x="p_Root2", y="Power", hue="Location change in population", col="Change",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data= results1, x="tau_AB2", y="Power", hue="Change", col="Location change in length",
    capsize=.2, palette="YlGnBu_d", errorbar="ci",
    kind="point", height=6, aspect=.75,
)
g.despine(left=True)
# Out:
# C:\Users\elian\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
